# %%
import cymetric as cym
from cymetric import metric

def read_db(filename):
    db = cym.dbopen(filename)
    return db

def get_table(db, table_name):
    # Resources, Materials, Products, Recipes, Compostions, TimeSeriesEnrichmentFeed, TimeSeriesEnrichmentSWU, Transactions
    evaler = cym.Evaluator(db)
    return evaler.eval(table_name)# if attr is not None else 

def get_data(table, attr, func):
    return table[func(table[attr])]
    # return table[attr]
    
def func(x, cmp=None):
    return x==x if cmp is None else cmp(x)

def get_commodity(db, cmd=None):
    # Commodity lists or df for given commodity
    table = get_table(db,'Transactions')
    return table.Commodity.unique() if cmd is None else table[table.Commodity==cmd]

def get_recipe(db):
    # Return recipe name and QualId
    recipe = get_table(db, 'Recipes')
    return recipe.Recipe.unique(), recipe.QualId.unique()

class CyclusData:
    def __init__(self, filename):
        db = cym.dbopen(filename)
        self.db = db
    def transactions(self):
        self.transactions_table = get_table(self.db,'Transactions')
        return self.transactions_table
    def resources(self):
        self.resources_table = get_table(self.db,'Resources')
        return self.resources_table
    def compositions(self):
        self.compositions_table = get_table(self.db,'Compositions')
        return self.compostions_table
    def materials(self):
        self.materials_table = get_table(self.db,'Materials')
        return self.materials_table
    def tables(self):
        self.tables = self.db.tables
        return self.tables
    def get_table(self, attr):
        self.select_table = get_table(self.db, attr)
        return self.select_table
    # Time Series Transaction Query
    def get_time_transaction(self,commod=None, rec=None, send=None):
        # return resources
        if not hasattr(self, 'transactions_table'):
        #if self.transactions_table is None:
            self.transactions()
        selections = []
        if commod is not None:
            selections.append(self.transactions_table.Commodity==commod)
        if rec is not None:
            selections.append(self.transactions_table.ReceiverId==rec)
        if send is not None:
            selections.append(self.transactions_table.SenderId==send)
        if len(selections)==0:
            return self.transactions_table
        elif len(selections)==1:
            return self.transactions_table[selections[0]]
        else:
            sel = selections[0]
            for i in range(1, len(selections)):
                sel = sel & selections[i]
            
            return self.transactions_table[sel]
    def get_time_commod(self,commod=None, rec=None, send=None):
        selectionrId = self.get_time_transaction(commod, rec, send)
        if not hasattr(self, 'resources_table'):
            self.resources()
            df = self.resources_table
            return df.loc[df['ResourceId'].isin(selectionrId.ResourceId)]
    #def get_time_resource()
    def get_agent_entry(self, prototype=None, kind=None):
        # Return Entry Table for selection
        tb = get_table(self.db, 'AgentEntry')
        if prototype is not None:
            return tb[tb.Prototype == prototype]
        if kind is not None:
            return tb[tb.Kind == kind]
            
        
    def get_agent_exit(self, prototype=None, kind=None):
        # Return Exit Table for selection
        entertb = get_table(self.db, 'AgentEntry')
        exittb = get_table(self.db, 'AgentExit')
        if prototype is not None:
            #entertb.loc[entertb.Pro]
            stb = entertb[entertb.Prototype == prototype]
            return exittb.loc[exittb.AgentId.isin(stb.AgentId)]

# %%
# Create CyclusData Class
cdt = CyclusData('data/new2.sqlite')
cdt.get_agent_entry(prototype='lwr')
#cdt.tables()
# Out:
#                                     SimId  AgentId      Kind  \
# 11   52666bac-8957-4cbb-8d77-95a925f1db0c       46  Facility
# 12   52666bac-8957-4cbb-8d77-95a925f1db0c       47  Facility
# 776  52666bac-8957-4cbb-8d77-95a925f1db0c      811  Facility
# 777  52666bac-8957-4cbb-8d77-95a925f1db0c      812  Facility
# 778  52666bac-8957-4cbb-8d77-95a925f1db0c      813  Facility
# 779  52666bac-8957-4cbb-8d77-95a925f1db0c      814  Facility
# 787  52666bac-8957-4cbb-8d77-95a925f1db0c      822  Facility
# 788  52666bac-8957-4cbb-8d77-95a925f1db0c      823  Facility
# 789  52666bac-8957-4cbb-8d77-95a925f1db0c      824  Facility
# 790  52666bac-8957-4cbb-8d77-95a925f1db0c      825  Facility
# 791  52666bac-8957-4cbb-8d77-95a925f1db0c      826  Facility
# 792  52666bac-8957-4cbb-8d77-95a925f1db0c      827  Facility
# 793  52666bac-8957-4cbb-8d77-95a925f1db0c      828  Facility
# 794  52666bac-8957-4cbb-8d77-95a925f1db0c      829  Facility
# 795  52666bac-8957-4cbb-8d77-95a925f1db0c      830  Facility
# 796  52666bac-8957-4cbb-8d77-95a925f1db0c      831  Facility
# 797  52666bac-8957-4cbb-8d77-95a925f1db0c      832  Facility
# 798  52666bac-8957-4cbb-8d77-95a925f1db0c      833  Facility
#
#                   Spec Prototype  ParentId  Lifetime  EnterTime
# 11   :cycamore:Reactor       lwr        45       480          1
# 12   :cycamore:Reactor       lwr        45       480          1
# 13   :cycamore:Reactor       lwr        45       480          1
# 14   :cycamore:Reactor       lwr        45       480         49
# 15   :cycamore:Reactor       lwr        45       480         49
# 16   :cycamore:Reactor       lwr        45       480         97
# 17   :cycamore:Reactor       lwr        45       480         97
# 18   :cycamore:Reactor       lwr        45       480        145
# 19   :cycamore:Reactor       lwr        45       480        145
# 20   :cycamore:Reactor       lwr        45       480        193
# 21   :cycamore:Reactor       lwr        45       480        193
# 22   :cycamore:Reactor       lwr        45       480        241
# 23   :cycamore:Reactor       lwr        45       480        289
# 24   :cycamore:Reactor       lwr        45       480        337
# 28   :cycamore:Reactor       lwr        45       480        433
# 29   :cycamore:Reactor       lwr        45       480        469
# 30   :cycamore:Reactor       lwr        45       480        481
# 31   :cycamore:Reactor       lwr        45       480        481
# 32   :cycamore:Reactor       lwr        45       480        481
# 34   :cycamore:Reactor       lwr        45       480        529
# 35   :cycamore:Reactor       lwr        45       480        529
# 36   :cycamore:Reactor       lwr        45       480        529
# 37   :cycamore:Reactor       lwr        45       480        553
# 38   :cycamore:Reactor       lwr        45       480        577
# 39   :cycamore:Reactor       lwr        45       480        577
# 40   :cycamore:Reactor       lwr        45       480        589
# 41   :cycamore:Reactor       lwr        45       480        625
# 42   :cycamore:Reactor       lwr        45       480        625
# 43   :cycamore:Reactor       lwr        45       480        625
# 45   :cycamore:Reactor       lwr        45       480        661
# ..                 ...       ...       ...       ...        ...
# 761  :cycamore:Reactor       lwr        45       480       2365
# 762  :cycamore:Reactor       lwr        45       480       2365
# 763  :cycamore:Reactor       lwr        45       480       2365
# 764  :cycamore:Reactor       lwr        45       480       2365
# 765  :cycamore:Reactor       lwr        45       480       2365
# 766  :cycamore:Reactor       lwr        45       480       2365
# 767  :cycamore:Reactor       lwr        45       480       2365
# 768  :cycamore:Reactor       lwr        45       480       2365
# 770  :cycamore:Reactor       lwr        45       480       2377
# 771  :cycamore:Reactor       lwr        45       480       2377
# 772  :cycamore:Reactor       lwr        45       480       2377
# 773  :cycamore:Reactor       lwr        45       480       2377
# 774  :cycamore:Reactor       lwr        45       480       2377
# 775  :cycamore:Reactor       lwr        45       480       2377
# 776  :cycamore:Reactor       lwr        45       480       2377
# 777  :cycamore:Reactor       lwr        45       480       2377
# 778  :cycamore:Reactor       lwr        45       480       2377
# 779  :cycamore:Reactor       lwr        45       480       2377
# 787  :cycamore:Reactor       lwr        45       480       2389
# 788  :cycamore:Reactor       lwr        45       480       2389
# 789  :cycamore:Reactor       lwr        45       480       2389
# 790  :cycamore:Reactor       lwr        45       480       2389
# 791  :cycamore:Reactor       lwr        45       480       2389
# 792  :cycamore:Reactor       lwr        45       480       2389
# 793  :cycamore:Reactor       lwr        45       480       2389
# 794  :cycamore:Reactor       lwr        45       480       2389
# 795  :cycamore:Reactor       lwr        45       480       2389
# 796  :cycamore:Reactor       lwr        45       480       2389
# 797  :cycamore:Reactor       lwr        45       480       2389
# 798  :cycamore:Reactor       lwr        45       480       2389
#
# [627 rows x 8 columns]

# %%
cdt.get_agent_exit(prototype='lwr')
# Out:
#                                     SimId  AgentId  ExitTime
# 0    52666bac-8957-4cbb-8d77-95a925f1db0c       46       480
# 1    52666bac-8957-4cbb-8d77-95a925f1db0c       47       480
# 2    52666bac-8957-4cbb-8d77-95a925f1db0c       48       480
# 3    52666bac-8957-4cbb-8d77-95a925f1db0c       49       528
# 4    52666bac-8957-4cbb-8d77-95a925f1db0c       50       528
# 5    52666bac-8957-4cbb-8d77-95a925f1db0c       51       576
# 6    52666bac-8957-4cbb-8d77-95a925f1db0c       52       576
# 7    52666bac-8957-4cbb-8d77-95a925f1db0c       53       624
# 8    52666bac-8957-4cbb-8d77-95a925f1db0c       54       624
# 9    52666bac-8957-4cbb-8d77-95a925f1db0c       55       672
# 10   52666bac-8957-4cbb-8d77-95a925f1db0c       56       672
# 11   52666bac-8957-4cbb-8d77-95a925f1db0c       57       720
# 12   52666bac-8957-4cbb-8d77-95a925f1db0c       58       768
# 13   52666bac-8957-4cbb-8d77-95a925f1db0c       59       816
# 17   52666bac-8957-4cbb-8d77-95a925f1db0c       63       912
# 18   52666bac-8957-4cbb-8d77-95a925f1db0c       64       948
# 19   52666bac-8957-4cbb-8d77-95a925f1db0c       65       960
# 20   52666bac-8957-4cbb-8d77-95a925f1db0c       66       960
# 21   52666bac-8957-4cbb-8d77-95a925f1db0c       67       960
# 23   52666bac-8957-4cbb-8d77-95a925f1db0c       69      1008
# 24   52666bac-8957-4cbb-8d77-95a925f1db0c       70      1008
# 25   52666bac-8957-4cbb-8d77-95a925f1db0c       71      1008
# 26   52666bac-8957-4cbb-8d77-95a925f1db0c       72      1032
# 27   52666bac-8957-4cbb-8d77-95a925f1db0c       73      1056
# 28   52666bac-8957-4cbb-8d77-95a925f1db0c       74      1056
# 29   52666bac-8957-4cbb-8d77-95a925f1db0c       75      1068
# 30   52666bac-8957-4cbb-8d77-95a925f1db0c       77      1104
# 31   52666bac-8957-4cbb-8d77-95a925f1db0c       78      1104
# 32   52666bac-8957-4cbb-8d77-95a925f1db0c       76      1104
# 34   52666bac-8957-4cbb-8d77-95a925f1db0c       80      1140
# ..                                    ...      ...       ...
# 310  52666bac-8957-4cbb-8d77-95a925f1db0c      358      2328
# 311  52666bac-8957-4cbb-8d77-95a925f1db0c      357      2328
# 312  52666bac-8957-4cbb-8d77-95a925f1db0c      356      2328
# 313  52666bac-8957-4cbb-8d77-95a925f1db0c      359      2328
# 314  52666bac-8957-4cbb-8d77-95a925f1db0c      360      2328
# 316  52666bac-8957-4cbb-8d77-95a925f1db0c      362      2340
# 317  52666bac-8957-4cbb-8d77-95a925f1db0c      365      2340
# 318  52666bac-8957-4cbb-8d77-95a925f1db0c      364      2340
# 319  52666bac-8957-4cbb-8d77-95a925f1db0c      363      2340
# 323  52666bac-8957-4cbb-8d77-95a925f1db0c      369      2352
# 324  52666bac-8957-4cbb-8d77-95a925f1db0c      370      2352
# 325  52666bac-8957-4cbb-8d77-95a925f1db0c      371      2352
# 326  52666bac-8957-4cbb-8d77-95a925f1db0c      372      2352
# 327  52666bac-8957-4cbb-8d77-95a925f1db0c      373      2352
# 329  52666bac-8957-4cbb-8d77-95a925f1db0c      375      2364
# 330  52666bac-8957-4cbb-8d77-95a925f1db0c      376      2364
# 331  52666bac-8957-4cbb-8d77-95a925f1db0c      377      2364
# 332  52666bac-8957-4cbb-8d77-95a925f1db0c      378      2364
# 333  52666bac-8957-4cbb-8d77-95a925f1db0c      381      2364
# 334  52666bac-8957-4cbb-8d77-95a925f1db0c      379      2364
# 335  52666bac-8957-4cbb-8d77-95a925f1db0c      380      2364
# 336  52666bac-8957-4cbb-8d77-95a925f1db0c      382      2376
# 337  52666bac-8957-4cbb-8d77-95a925f1db0c      384      2376
# 339  52666bac-8957-4cbb-8d77-95a925f1db0c      383      2376
# 343  52666bac-8957-4cbb-8d77-95a925f1db0c      389      2388
# 344  52666bac-8957-4cbb-8d77-95a925f1db0c      391      2388
# 345  52666bac-8957-4cbb-8d77-95a925f1db0c      390      2388
# 346  52666bac-8957-4cbb-8d77-95a925f1db0c      392      2388
# 347  52666bac-8957-4cbb-8d77-95a925f1db0c      393      2388
# 348  52666bac-8957-4cbb-8d77-95a925f1db0c      394      2388
#
# [279 rows x 3 columns]

# %%
# Exmples on querying transaction
# cdt.get_time_transaction(commod='uox', rec = 46, send=39)
# Examples on querying commodity
# cdt.get_time_commod(commod='uox', rec = 46, send=39)
cdt.db.query('Agents')#.query('Agents')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-cc358fa829fd> in <module>()
#       3 # Examples on querying commodity
#       4 # cdt.get_time_commod(commod='uox', rec = 46, send=39)
# ----> 5 cdt.db.query('Agents')#.query('Agents')
#
# lib.pyx in cyclus.lib._FullBackend.query()
#
# RuntimeError: Invalid table name Agents
